# %%
import pandas as pd  # Data manipulation library
import numpy as np  # Numerical computing library
from dateutil import parser  # Date parsing library
import isodate  # ISO 8601 date and duration parsing library

# Data visualization libraries
import matplotlib.pyplot as plt  # Plotting library
import matplotlib.ticker as ticker  # Tick locator and formatter for Matplotlib
import seaborn as sns  # Statistical data visualization library
sns.set(style="darkgrid", color_codes=True)  # Set default style for Seaborn

# Google API
from googleapiclient.discovery import build  # Import the build function from Google API client

# %%
# NLP libraries
import nltk  # Natural Language Toolkit for NLP tasks
from nltk.corpus import stopwords  # Stopwords corpus from NLTK
from nltk.tokenize import word_tokenize  # Tokenization function from NLTK
nltk.download('stopwords')  # Download stopwords data from NLTK
nltk.download('punkt')  # Download tokenizer data from NLTK
from wordcloud import WordCloud  # Word cloud visualization library
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Justin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Justin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
api_key = 'assignedAPIKey'  # Replace 'assignedAPIKey' with your actual API key

channel_ids = [
    'UCc-N24Y5OA0gqbjBwe1ttfA',  # Weird History
    'UC-yCUq1xtoxlaCEpaBxHAeA',  # Nutty HIstory
    'UC88lvyJe7aHZmcvzvubDFRg',  # Timeline
    'UC4sEmXUuWIFlxRIFBRV6VXQ',  # The History Guy
    'UCv_vLHiWVBh_FR9vbeuiY-A'   # Civilis
]

youtube = build('youtube', 'v3', developerKey=api_key)  # Build the YouTube API client with the provided API key

# %%
#Import functions from Function.py
# %run -i functions.py

# %%
#calls the get_channel_stats function and passes the youtube object and channel_ids list as arguments. 
#It retrieves the channel statistics for the specified channel IDs and assigns the result to the channel_data variable.

channel_data = get_channel_stats(youtube, channel_ids)

# %%
channel_data
# Out:
#                                          channelName subscribers       views  \
# 0                                   Historia Civilis      923000   114737879
# 1  The History Guy: History Deserves to Be Rememb...     1220000   203210642
# 2                                      Nutty History      593000    90650832
# 3             Timeline - World History Documentaries     4790000  1104179987
# 4                                      Weird History     4260000   568361393
#
#   totalVideos                playlistId
# 0          84  UUv_vLHiWVBh_FR9vbeuiY-A
# 1        1025  UU4sEmXUuWIFlxRIFBRV6VXQ
# 2         340  UU-yCUq1xtoxlaCEpaBxHAeA
# 3        1109  UU88lvyJe7aHZmcvzvubDFRg
# 4         684  UUc-N24Y5OA0gqbjBwe1ttfA

# %%
# Convert count columns to numeric columns
numeric_cols = ['subscribers', 'views', 'totalVideos']
channel_data[numeric_cols] = channel_data[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %%
# Set the figure size for the seaborn plot
sns.set(rc={'figure.figsize':(10,8)})

# Create the bar plot
ax = sns.barplot(x='channelName', y='subscribers', data=channel_data.sort_values('subscribers', ascending=False))

# Format the y-axis labels to display in thousands
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'K'))

# Rotate the x-axis labels for better readability
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
ax = sns.barplot(x='channelName', y='views', data=channel_data.sort_values('views', ascending=False))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'K'))
plot = ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %%
video_frames = []  # List to store individual video dataframes
comments_frames = []  # List to store individual comment dataframes

# Iterate over unique channel names in channel_data
for c in channel_data['channelName'].unique():
    print("Getting video information from channel: " + c)
    
    # Get the playlist ID for the current channel
    playlist_id = channel_data.loc[channel_data['channelName'] == c, 'playlistId'].iloc[0]
    
    # Get the video IDs from the playlist
    video_ids = get_video_ids(youtube, playlist_id)
    
    # Get video data for the video IDs
    video_data = get_video_details(youtube, video_ids)
    
    # Get comment data for the video IDs
    comments_data = get_comments_in_videos(youtube, video_ids)
    
    # Append the video data and comment data to their respective frames
    video_frames.append(video_data)
    comments_frames.append(comments_data)

# Combine all the video dataframes into a single dataframe
video_df = pd.concat(video_frames, ignore_index=True)

# Combine all the comment dataframes into a single dataframe
comments_df = pd.concat(comments_frames, ignore_index=True)
# Out:
# Getting video information from channel: Nutty History
# Getting video information from channel: Historia Civilis
# Getting video information from channel: Timeline - World History Documentaries
# Could not get comments for video UZMb527fHuQ
# Getting video information from channel: The History Guy: History Deserves to Be Remembered
# Could not get comments for video 8TP1cxC7NDc
# Could not get comments for video 4DgcbC7qu10
# Could not get comments for video nauaIbOXaYo
# Could not get comments for video pkR3DqnXhIk
# Could not get comments for video BIqrNF--gks
# Getting video information from channel: Weird History
# Could not get comments for video 5adOMpj9KEA
# Could not get comments for video 2yXb8pjrzag

# %%
video_df
# Out:
#          video_id   channelTitle  \
# 0     zqK8qxUc-rU  Nutty History
# 1     VYW7bFRIqPA  Nutty History
# 2     NK9T9UVpM4E  Nutty History
# 3     -Pm9Q7_VV70  Nutty History
# 4     vEkCW5aZDsw  Nutty History
# ...           ...            ...
# 3188  O8BYlD9uiB4  Weird History
# 3189  oo4cP-rb7Ag  Weird History
# 3190  0NuHa_Npza0  Weird History
# 3191  W9q0plyu764  Weird History
# 3192  jV4YzOwMu6I  Weird History
#
#                                                   title  \
# 0      Creepy Things That Were Normal in Constantinople
# 1                         The Filthy Hygiene of Mongols
# 2            The Forgotten Country that Destroyed Egypt
# 3     Filthy Secret Lives of Bandits on the American...
# 4             Why Life in English Parliament was Brutal
# ...                                                 ...
# 3188    Julius Caesar Was Kidnapped By Cilician Pirates
# 3189             Jesus Christ Was NOT Born On Christmas
# 3190  President Theodore Roosevelt Delivered A Speec...
# 3191  Greek Playwright Aeschylus Was Killed By a Turtle
# 3192  The Disturbing Truth About Mother Teresa You N...
#
#                                             description  \
# 0     In the fabled city of Constantinople, where th...
# 1     Within the heart of the vast, untamed Eurasian...
# 2     In the shadowy folds of history, where ancient...
# 3     Enter the thrilling, lawless world of the Wild...
# 4     Imagine a grand stage where history unfolded i...
# ...                                                 ...
# 3188  Here’s a completely bad ass Julius Caesar stor...
# 3189  Did you know that Jesus Christ was NOT actuall...
# 3190  There are many Teddy Roosevelt facts out there...
# 3191  Ever heard of the playwright Aeschylus? Well h...
# 3192  It's time to rethink all the Mother Teresa fac...
#
#                                                    tags           publishedAt  \
# 0     [Creepy Things That Were Normal in Constantino...  2023-05-30T19:00:25Z
# 1     [What Hygiene was like for the Mongols, Mongol...  2023-05-26T19:00:12Z
# 2     [What Happened to Egypt After Battling the Kus...  2023-05-23T19:00:17Z
# 3     [Wild West, Cowboy, Butch Cassidy, Robert LeRo...  2023-05-20T19:00:00Z
# 4     [English Parliament, Tudor Parliament, Henry V...  2023-05-17T19:30:03Z
# ...                                                 ...                   ...
# 3188  [julius caesar, julius caesar pirates, julius ...  2017-06-16T17:35:11Z
# 3189  [Jesus Christ Birth Date, Jesus Christ Birthda...  2017-06-15T18:01:43Z
# 3190  [Theodore Roosevelt, President Roosevelt, Theo...  2017-06-14T16:14:56Z
# 3191  [Aeschlus Playwright, Aeschylus, Aeschylus Dea...  2017-06-13T20:28:53Z
# 3192  [mother teresa, the unfortunate truth of mothe...  2017-06-13T19:10:40Z
#
#      viewCount likeCount favouriteCount commentCount  duration definition  \
# 0        26555      1188           None          104  PT22M24S         hd
# 1        61900      2133           None           81  PT14M46S         hd
# 2        49845      1824           None          207   PT19M1S         hd
# 3        79218      2208           None           73  PT22M14S         hd
# 4        34009      1380           None           43  PT21M50S         hd
# ...        ...       ...            ...          ...       ...        ...
# 3188     28695       778           None           36   PT1M26S         hd
# 3189     26217       704           None          109   PT1M36S         hd
# 3190     42932      1101           None           77   PT1M28S         hd
# 3191     31603       811           None           37   PT1M29S         hd
# 3192    652495     15074           None         3756   PT3M33S         hd
#
#      caption
# 0      false
# 1      false
# 2      false
# 3      false
# 4      false
# ...      ...
# 3188   false
# 3189   false
# 3190   false
# 3191   false
# 3192   false
#
# [3193 rows x 13 columns]

# %%
comments_df
# Out:
#          video_id                                           comments
# 0     zqK8qxUc-rU  [so i was waiting some maniac facts when u say...
# 1     VYW7bFRIqPA  [Clean clothes are actually warmer., After the...
# 2     NK9T9UVpM4E  [Taharqa is the Biblical "Tirhakah" (Heb: תִּר...
# 3     -Pm9Q7_VV70  [I truly enjoy your channel, Can we get a vide...
# 4     vEkCW5aZDsw  [His petticoat caught fire. He was wearing a d...
# ...           ...                                                ...
# 3180  O8BYlD9uiB4  [Fun fact: he actually promised that he would ...
# 3181  oo4cP-rb7Ag  [Cuss jesus did not exist, so Christmas should...
# 3182  0NuHa_Npza0  [Even five years ago Jordan knew to at least b...
# 3183  W9q0plyu764  [Sometimes as an Orthodox Christian, I think t...
# 3184  jV4YzOwMu6I  [What about those who are doing in the secret ...
#
# [3185 rows x 2 columns]

# %%
# write vid data o CSV
video_df.to_csv('video_data_top10_channels.csv')
comments_df.to_csv('comments_data_top10_channels.csv')

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount          True
# favouriteCount     True
# commentCount       True
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_df.publishedAt.sort_values().value_counts()
# Out:
# publishedAt
# 2017-02-03T17:30:02Z    2
# 2021-09-14T13:00:09Z    2
# 2017-11-12T00:00:00Z    2
# 2014-08-14T18:00:10Z    1
# 2021-10-22T14:00:05Z    1
#                        ..
# 2020-01-29T13:10:20Z    1
# 2020-01-29T15:00:03Z    1
# 2020-01-30T18:00:12Z    1
# 2020-01-31T13:21:11Z    1
# 2023-05-31T14:00:03Z    1
# Name: count, Length: 3190, dtype: int64

# %%
cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[cols] = video_df[cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
# Add number of tags
video_df['tagsCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
# Comments and likes per 1000 view ratio
video_df['likeRatio'] = video_df['likeCount']/ video_df['viewCount'] * 1000
video_df['commentRatio'] = video_df['commentCount']/ video_df['viewCount'] * 1000

# %%
# Title character length
video_df['titleLength'] = video_df['title'].apply(lambda x: len(x))

# %%
video_df.head()
# Out:
#       video_id   channelTitle  \
# 0  zqK8qxUc-rU  Nutty History
# 1  VYW7bFRIqPA  Nutty History
# 2  NK9T9UVpM4E  Nutty History
# 3  -Pm9Q7_VV70  Nutty History
# 4  vEkCW5aZDsw  Nutty History
#
#                                                title  \
# 0   Creepy Things That Were Normal in Constantinople
# 1                      The Filthy Hygiene of Mongols
# 2         The Forgotten Country that Destroyed Egypt
# 3  Filthy Secret Lives of Bandits on the American...
# 4          Why Life in English Parliament was Brutal
#
#                                          description  \
# 0  In the fabled city of Constantinople, where th...
# 1  Within the heart of the vast, untamed Eurasian...
# 2  In the shadowy folds of history, where ancient...
# 3  Enter the thrilling, lawless world of the Wild...
# 4  Imagine a grand stage where history unfolded i...
#
#                                                 tags  \
# 0  [Creepy Things That Were Normal in Constantino...
# 1  [What Hygiene was like for the Mongols, Mongol...
# 2  [What Happened to Egypt After Battling the Kus...
# 3  [Wild West, Cowboy, Butch Cassidy, Robert LeRo...
# 4  [English Parliament, Tudor Parliament, Henry V...
#
#                 publishedAt  viewCount  likeCount  favouriteCount  \
# 0 2023-05-30 19:00:25+00:00    26555.0     1188.0             NaN
# 1 2023-05-26 19:00:12+00:00    61900.0     2133.0             NaN
# 2 2023-05-23 19:00:17+00:00    49845.0     1824.0             NaN
# 3 2023-05-20 19:00:00+00:00    79218.0     2208.0             NaN
# 4 2023-05-17 19:30:03+00:00    34009.0     1380.0             NaN
#
#    commentCount  duration definition caption pushblishDayName    durationSecs  \
# 0         104.0  PT22M24S         hd   false          Tuesday 0 days 00:22:24
# 1          81.0  PT14M46S         hd   false           Friday 0 days 00:14:46
# 2         207.0   PT19M1S         hd   false          Tuesday 0 days 00:19:01
# 3          73.0  PT22M14S         hd   false         Saturday 0 days 00:22:14
# 4          43.0  PT21M50S         hd   false        Wednesday 0 days 00:21:50
#
#    tagsCount  likeRatio  commentRatio  titleLength  \
# 0         23  44.737338      3.916400           48
# 1         27  34.458805      1.308562           29
# 2         32  36.593440      4.152874           42
# 3         26  27.872453      0.921508           55
# 4         23  40.577494      1.264371           41
#
#                                   title_no_stopwords
# 0  [Creepy, Things, That, Were, Normal, Constanti...
# 1                    [The, Filthy, Hygiene, Mongols]
# 2        [The, Forgotten, Country, Destroyed, Egypt]
# 3  [Filthy, Secret, Lives, Bandits, American, Fro...
# 4           [Why, Life, English, Parliament, Brutal]

# %%
plt.rcParams['figure.figsize'] = (18, 6)
sns.violinplot(x='channelTitle', y='viewCount', data=video_df, palette='pastel')
plt.title('Views per channel', fontsize=14)
plt.show()

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(data = video_df, x = "commentCount", y = "viewCount", ax=ax[0])
sns.scatterplot(data = video_df, x = "likeCount", y = "viewCount", ax=ax[1])
# Out:
# <Axes: xlabel='likeCount', ylabel='viewCount'>

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(data = video_df, x = "commentRatio", y = "viewCount", ax=ax[0])
sns.scatterplot(data = video_df, x = "likeRatio", y = "viewCount", ax=ax[1])
# Out:
# <Axes: xlabel='likeRatio', ylabel='viewCount'>

# %%
sns.scatterplot(data = video_df, x = "titleLength", y = "viewCount")
# Out:
# <Axes: xlabel='titleLength', ylabel='viewCount'>

# %%
# Set the stop words for English language
stop_words = set(stopwords.words('english'))

# Apply stop word removal to the 'title' column of the video_df DataFrame
video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

# Create a list of all words in the 'title_no_stopwords' column
all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])

# Join all the words into a single string
all_words_str = ' '.join(all_words)

# %%
# Define a function to plot the word cloud
def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud)
    plt.axis("off")

# Generate the word cloud using the 'all_words_str' string
wordcloud = WordCloud(width=2000, height=1000, random_state=1, background_color='black',
                      colormap='viridis', collocations=False).generate(all_words_str)

# Plot the word cloud using the defined function
plot_cloud(wordcloud)

# %%
sns.scatterplot(data = video_df, x = "tagsCount", y = "viewCount")
# Out:
# <Axes: xlabel='tagsCount', ylabel='viewCount'>

# %%
# Set the stop words for English language
stop_words = set(stopwords.words('english'))

# Remove stop words from the 'comments' column and store the result in a new column 'comments_no_stopwords'
comments_df['comments_no_stopwords'] = comments_df['comments'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

# Create a list of all words in the 'comments_no_stopwords' column
all_words = list([a for b in comments_df['comments_no_stopwords'].tolist() for a in b])

# Join all the words in the 'all_words' list into a single string
all_words_str = ' '.join(all_words)

# %%
# Create a WordCloud object with specified settings
wordcloud = WordCloud(
    width=2000, height=1000, random_state=1, background_color='black',
    colormap='viridis', collocations=False
).generate(all_words_str)

# Create a plot for the word cloud
plt.figure(figsize=(30, 20))
plt.imshow(wordcloud)
plt.axis("off")

# Show the plot
plt.show()
